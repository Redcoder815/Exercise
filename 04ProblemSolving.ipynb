# %% [markdown]
# <a href="https://colab.research.google.com/github/Redcoder815/Exercise/blob/main/04ProblemSolving.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def introduce(name, age):
  print(f"My name is {name} and I am {age} years old")

# %%
introduce("Rahim", 28)
# Out:
# My name is Rahim and I am 28 years old

# %%
data = [1, 2, 3, 4, 5, 6, 7, 8]
batch_size = 3

def batch_generator(batch_size, data):
  for i in range(0, len(data), batch_size):
    yield data[i:i+batch_size]

# %%
x = batch_generator(batch_size, data)

print(next(x))
print(next(x))
print(next(x))
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8]

# %%
numbers = [1, 2, 3, 4]

squared_numbers = list(map(lambda x : x ** 2, numbers))

print(squared_numbers)
# Out:
# [1, 4, 9, 16]

# %%
def power(base, exponent = 2):
  return base ** exponent

# %%
print(power(5))
print(power(5, 3))
# Out:
# 25
# 125

# %%
list_of_numbers = [1, 2, 3, 4, 5, 6]

even_numbers = list(filter(lambda x: x % 2 == 0, list_of_numbers))

even_squared_numbers = list(map(lambda x: x ** 2, even_numbers))

print(even_squared_numbers)
# Out:
# [4, 16, 36]
